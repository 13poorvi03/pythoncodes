# %%
s = {1,2,3,4,5}
s1 = {3,4,5,6,7,8}
print("union",s|s1)
print("intersection",s&s1)
print("difference",s-s1)
print("symmetric differnce",s^s1)
# Out:
# union {1, 2, 3, 4, 5, 6, 7, 8}
# intersection {3, 4, 5}
# difference {1, 2}
# symmetric differnce {1, 2, 6, 7, 8}

# %%
st = {1,3,4,5}
st.add((3,4,5))
print(st)
# st.add([30,40,5])
# print(st)
st.update((30,40,5))
print(st)
st.update([300,40,50])
print(st)
# Out:
# {1, 3, 4, 5, (3, 4, 5)}
# {1, 3, 4, 5, 40, (3, 4, 5), 30}
# {1, 3, 4, 5, 40, 300, 50, (3, 4, 5), 30}

# %%
st={1,2,3,1,2,3,'hello',3.5,(4,5,3,6)}
# st.add(20)
st.add((20,3,4))
st.update((50,73,22))
print(st)
# Out:
# {1, 2, 3.5, 3, 73, 'hello', (20, 3, 4), 22, (4, 5, 3, 6), 50}

# %%
st={1,2,3,1,2,3,'hello',3.5}

del st

# %%
l = {12,23,34,45,67,75,64}
# remove 23 
l.remove(23)
l.discard(30)
l.discard(45)
print(l)
# Out:
# {64, 34, 67, 75, 12}

# %%
st1 = {1,2,3,1,2,3,'hello',3.5}
for i in st1:
    print(i, end= " ")
# Out:
# 1 2 3.5 3 hello

# %%
st1 = {1,2,3,1,2,3,'hello',3.5}
print(st1)
# Out:
# {1, 2, 3.5, 3, 'hello'}

# %%
st = set()
st1 = {}
print(st)
print(type(st))
print(type(st1))
# Out:
# set()
# <class 'set'>
# <class 'dict'>
