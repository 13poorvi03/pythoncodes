# %%
# variablesss

first_name = 'poorvi'
last_name = 'sharma'
print(first_name)
print(last_name)

skills=['html','CSS','python','CSS']
print(skills)

# finding length of varible
print(len(first_name))

your_name, your_lastname,country,age = 'poorvi','sharma','india','20'
print(your_name, your_lastname,country,age)
# Out:
# poorvi
# sharma
# ['html', 'CSS', 'python', 'CSS']
# 6
# poorvi sharma india 20

# %%
# taking input 

your_name = input('enter your name :')
age = input('enter your age : ')
print(your_name)
print(age)
# Out:
# poorvi
# 20

# %%
# data type 

ur_name = 'poorvi'
last_name = 'sharma'
print(type(ur_name))
print(type(last_name))

print(type((1,2,3)))
print(type(10))
print(type([1,2,3,4]))
print(type(3.4))
print(type({'name':'poorvi'}))
print(type(True))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'tuple'>
# <class 'int'>
# <class 'list'>
# <class 'float'>
# <class 'dict'>
# <class 'bool'>

# %%
# Casting: Converting one data type to another data type

num_int =10
print(num_int)
print(type(num_int))

num_float = float(num_int)
print(type(num_float))

gravity=9.81
print(int(gravity))

num_intt = 10
print(num_intt)
num_str=str(num_int)
print(num_str)
# Out:
# 10
# <class 'int'>
# <class 'float'>
# 9
# 10
# 10

# %%
first_name='poorvi'
last_name= 'sharma'
full_name=first_name + last_name
print(full_name)

first_num = 4
second_num=5
total=first_num + second_num
multiply = first_num * second_num
division = first_num / second_num
flor_division = first_num // second_num
modulus = first_num % second_num
exponentiation = first_num ** second_num



print(total)
print(multiply)
print(division)
print(flor_division )
print(modulus)
print(exponentiation)
# Out:
# poorvisharma
# 9
# 20
# 0.8
# 0
# 4
# 1024
