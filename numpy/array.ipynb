# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
a = [1,2,3,4,5,"hellooo"]
a
# Out:
# [1, 2, 3, 4, 5, 'hellooo']

# %%
np.array(a)
# Out:
# array(['1', '2', '3', '4', '5', 'hellooo'], dtype='<U21')

# %%
l = [[1,2,3],[4,5,6],[7,8,9]]
l
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
np.array(l)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [7, 8, 9]])
